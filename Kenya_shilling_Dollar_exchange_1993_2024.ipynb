# %% [markdown]
# Irura Jackson Mwongera Notebook

# %% [markdown]
# # __Run this notebook online and  practice without installing both Python and Anaconda (Using Google Colab)__
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/IruraMwongera/irurajackblogs/blob/main/Kenya_shilling_Dollar_exchange_1993_2024.ipynb)

# %% [markdown]
# ### This data consists of Kenya shilling exchage with US dollar since 1991 to 2024.
# ### Now if you feel you can do some data analysis using python try this data.
# ### I have added another column for presidents.This column will allow you to do analysis and determine presidency regime that affected Kenyan shilling to drop drastically when subjected to us dollar.
# ### Try also to determine years when there was drastic fall of Kenyan shilling when subjected to Us dollar,,,google what was happening in Kenya in those years and in the world in general then conclude factors that leads to kenyan shilling to fall when subjected to US dollar.
#
# ### After you complete your analysis go to Files and download your jupyter notebook.Send it to me  through email irura.mwongera11@gmail.com,,,let learn together I am also doing the same project currently.
#
# ### __Note.You don't need to install Python and Anaconda to run do this project,,,since I have intengrated  google colab with this jupyter notebook,All you need (Just click colab tab above and run your codes on this notebook).__

# %%
import pandas as pd

# %%
from urllib.request import urlretrieve

# %% [markdown]
# ## __First we import shilling_dollar data from github using this url__

# %%
dollar_shilling_exchange_url ='https://raw.githubusercontent.com/IruraMwongera/irurajackblogs/main/USD_KES_Historical_Data.csv'

# %%
urlretrieve(dollar_shilling_exchange_url, 'USD_KES_Historical_Data.csv')
# Out:
# ('USD_KES_Historical_Data.csv', <http.client.HTTPMessage at 0x7e7f1aae5240>)

# %%
try:
    dollar_shilling_exchange = pd.read_csv('USD_KES_Historical_Data.csv')
    print(dollar_shilling_exchange.head())  # Properly display the dataframe's head
except pd.errors.ParserError as e:
    print("ParserError:", e)
except Exception as e:
    print("An error occurred:", e)
# Out:
#          Date   Price     Open     High     Low  Vol. Change %
# 0  08/01/2024  129.50  129.000  130.000  128.99   NaN    0.39%
# 1  07/01/2024  129.00  129.380  133.000  127.13   NaN   -0.29%
# 2  06/01/2024  129.38  132.904  132.904  128.00   NaN   -0.48%
# 3  05/01/2024  130.00  135.000  136.000  128.10   NaN   -3.35%
# 4  04/01/2024  134.50  131.500  135.000  129.35   NaN    2.48%

# %%
dollar_shilling_exchange.head(10)
# Out:
#          Date   Price     Open     High     Low  Vol. Change %
# 0  08/01/2024  129.50  129.000  130.000  128.99   NaN    0.39%
# 1  07/01/2024  129.00  129.380  133.000  127.13   NaN   -0.29%
# 2  06/01/2024  129.38  132.904  132.904  128.00   NaN   -0.48%
# 3  05/01/2024  130.00  135.000  136.000  128.10   NaN   -3.35%
# 4  04/01/2024  134.50  131.500  135.000  129.35   NaN    2.48%
# 5  03/01/2024  131.25  146.750  147.000  130.85   NaN  -10.41%
# 6  02/01/2024  146.50  160.500  161.000  139.50   NaN   -8.44%
# 7  01/01/2024  160.00  157.000  163.500  156.35   NaN    2.24%
# 8  12/01/2023  156.50  153.300  157.000  153.00   NaN    2.19%
# 9  11/01/2023  153.15  150.750  153.300  150.55   NaN    1.79%

# %% [markdown]
# ### __Let convert Date from Object to datetime__

# %%
dollar_shilling_exchange['Date'] = pd.to_datetime(dollar_shilling_exchange['Date'])

# %% [markdown]
# ### __Let See Information of our Dataframe(pandas)__

# %%
dollar_shilling_exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      404 non-null    datetime64[ns]
#  1   Price     404 non-null    float64
#  2   Open      404 non-null    float64
#  3   High      404 non-null    float64
#  4   Low       404 non-null    float64
#  5   Vol.      0 non-null      float64
#  6   Change %  404 non-null    object
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 22.2+ KB

# %% [markdown]
# ### We can see that date as changed fro object to datetime

# %% [markdown]
# ### __Let drop column "Vol." Since it is empty__

# %%
dollar_shilling_exchange.drop(columns = ["Vol."],inplace = True)

# %%
dollar_shilling_exchange.head(5)
# Out:
#         Date   Price     Open     High     Low Change %
# 0 2024-08-01  129.50  129.000  130.000  128.99    0.39%
# 1 2024-07-01  129.00  129.380  133.000  127.13   -0.29%
# 2 2024-06-01  129.38  132.904  132.904  128.00   -0.48%
# 3 2024-05-01  130.00  135.000  136.000  128.10   -3.35%
# 4 2024-04-01  134.50  131.500  135.000  129.35    2.48%

# %%
dollar_shilling_exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      404 non-null    datetime64[ns]
#  1   Price     404 non-null    float64
#  2   Open      404 non-null    float64
#  3   High      404 non-null    float64
#  4   Low       404 non-null    float64
#  5   Change %  404 non-null    object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 19.1+ KB

# %% [markdown]
# ### __Let add president column in our dataframe__

# %%
# Extract the year from the date column
dollar_shilling_exchange['year'] = dollar_shilling_exchange['Date'].dt.year

# Define the function to map years to presidents
def get_president(year):
    if 1978 <= year <= 2002:
        return 'Daniel arap Moi'
    elif 2003 <= year <= 2013:
        return 'Mwai Kibaki'
    elif 2014 <= year <= 2022:
        return 'Uhuru Kenyatta'
    elif year >= 2023:
        return 'William Ruto'
    else:
        return None

# Apply the function to the DataFrame to create a new column for presidents
dollar_shilling_exchange['president'] = dollar_shilling_exchange['year'].apply(get_president)

# Drop the 'year' column if it's not needed
dollar_shilling_exchange= dollar_shilling_exchange.drop(columns=['year'])

# %%
dollar_shilling_exchange
# Out:
#           Date    Price     Open     High      Low Change %        president
# 0   2024-08-01  129.500  129.000  130.000  128.990    0.39%     William Ruto
# 1   2024-07-01  129.000  129.380  133.000  127.130   -0.29%     William Ruto
# 2   2024-06-01  129.380  132.904  132.904  128.000   -0.48%     William Ruto
# 3   2024-05-01  130.000  135.000  136.000  128.100   -3.35%     William Ruto
# 4   2024-04-01  134.500  131.500  135.000  129.350    2.48%     William Ruto
# ..         ...      ...      ...      ...      ...      ...              ...
# 399 1991-05-01   27.811   27.769   27.811   27.769    0.10%  Daniel arap Moi
# 400 1991-04-01   27.782   27.740   27.782   27.740    4.46%  Daniel arap Moi
# 401 1991-03-01   26.596   26.556   26.596   26.556    5.52%  Daniel arap Moi
# 402 1991-02-01   25.205   25.167   25.205   25.167    1.96%  Daniel arap Moi
# 403 1991-01-01   24.721   24.684   24.721   24.684    2.64%  Daniel arap Moi
#
# [404 rows x 7 columns]
